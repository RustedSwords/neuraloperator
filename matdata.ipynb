# %%
from scipy.io import loadmat
import pandas as pd

# %%
mat = loadmat('/home/rusted/Projects/Thesis/neuraloperator/data/burgers_data_R10.mat')

# %%
burgersr10a = pd.DataFrame(mat.get('a'))
burgersr10u = pd.DataFrame(mat.get('u'))

# %%
burgersr10a
# Out:
#           0         1         2         3         4         5         6     \
# 0     0.835411  0.835342  0.835271  0.835198  0.835122  0.835044  0.834965
# 1     0.474078  0.473847  0.473619  0.473394  0.473172  0.472952  0.472735
# 2    -0.380157 -0.380742 -0.381330 -0.381920 -0.382512 -0.383106 -0.383702
# 3    -0.446522 -0.446220 -0.445914 -0.445604 -0.445288 -0.444969 -0.444644
# 4     0.004025  0.004414  0.004805  0.005198  0.005592  0.005987  0.006384
# ...        ...       ...       ...       ...       ...       ...       ...
# 2043  0.532406  0.531917  0.531426  0.530935  0.530442  0.529948  0.529452
# 2044  1.515834  1.514981  1.514127  1.513272  1.512416  1.511559  1.510701
# 2045  0.140281  0.139307  0.138335  0.137363  0.136391  0.135420  0.134449
# 2046  0.533108  0.532648  0.532187  0.531725  0.531263  0.530799  0.530335
# 2047  1.452471  1.451782  1.451086  1.450384  1.449676  1.448961  1.448240
#
# ...

# %%
burgersr10u
# Out:
#           0         1         2         3         4         5         6     \
# 0     0.683466  0.683666  0.683866  0.684065  0.684264  0.684463  0.684662
# 1     0.751108  0.751011  0.750913  0.750815  0.750717  0.750617  0.750518
# 2    -0.415335 -0.415400 -0.415464 -0.415528 -0.415592 -0.415655 -0.415718
# 3    -0.249254 -0.249156 -0.249057 -0.248958 -0.248859 -0.248761 -0.248662
# 4    -0.016214 -0.015917 -0.015620 -0.015323 -0.015026 -0.014729 -0.014432
# ...        ...       ...       ...       ...       ...       ...       ...
# 2043  0.472264  0.472332  0.472400  0.472468  0.472535  0.472602  0.472669
# 2044  0.927155  0.927657  0.928159  0.928660  0.929162  0.929664  0.930165
# 2045  0.016046  0.015150  0.014254  0.013356  0.012458  0.011560  0.010661
# 2046  0.363100  0.363292  0.363483  0.363673  0.363863  0.364053  0.364243
# 2047  1.036372  1.036805  1.037238  1.037672  1.038105  1.038538  1.038971
#
# ...
